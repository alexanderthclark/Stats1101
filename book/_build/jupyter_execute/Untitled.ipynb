# %%
import ipywidgets
import matplotlib.pyplot as plt
import plotly

# %%
import plotly.graph_objects as go
import numpy as np
from scipy.stats import norm
import ipywidgets as widgets
from IPython.display import display

# Function to update the graph
def update_graph(variance):
    # Define the distribution parameters
    mean = 0
    variance = variance
    sigma = np.sqrt(variance)

    # Generate points for the x-axis
    x = np.linspace(mean - 3*sigma, mean + 3*sigma, 1000)
    y = norm.pdf(x, mean, sigma)

    # Update the plot
    with fig.batch_update():
        fig.data[0].x = x
        fig.data[0].y = y
        fig.layout.title.text = f'Normal Distribution with Variance: {variance}'

# Initial plot
initial_variance = 1
fig = go.FigureWidget(data=go.Scatter(x=[], y=[]))
update_graph(initial_variance)

# Slider widget for variance
variance_slider = widgets.FloatSlider(
    value=initial_variance,
    min=0.1,
    max=5.0,
    step=0.1,
    description='Variance:',
    continuous_update=False
)
variance_slider.observe(lambda change: update_graph(change.new), names='value')

# Display the widgets
display(variance_slider, fig)
# Out:
# FloatSlider(value=1.0, continuous_update=False, description='Variance:', max=5.0, min=0.1)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/anaconda3/lib/python3.11/site-packages/plotly/basewidget.py:741, in BaseFigureWidget._ipython_display_(self)
#     737 """
#     738 Handle rich display of figures in ipython contexts
#     739 """
#     740 # Override BaseFigure's display to make sure we display the widget version
# --> 741 widgets.DOMWidget._ipython_display_(self)
#
# AttributeError: type object 'DOMWidget' has no attribute '_ipython_display_'
# FigureWidget({
#     'data': [{'type': 'scatter',
# ...
